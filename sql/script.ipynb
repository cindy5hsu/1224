-- %% [markdown]
-- # [dbEvent]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [dbEvent]    Script Date: 2022/12/23 下午 04:34:45 ******/
CREATE DATABASE [dbEvent]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'dbevent', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.MSSQLSERVER\MSSQL\DATA\dbevent.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'dbevent_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.MSSQLSERVER\MSSQL\DATA\dbevent_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT
GO
ALTER DATABASE [dbEvent] SET COMPATIBILITY_LEVEL = 150
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [dbEvent].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [dbEvent] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [dbEvent] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [dbEvent] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [dbEvent] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [dbEvent] SET ARITHABORT OFF 
GO
ALTER DATABASE [dbEvent] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [dbEvent] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [dbEvent] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [dbEvent] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [dbEvent] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [dbEvent] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [dbEvent] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [dbEvent] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [dbEvent] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [dbEvent] SET  DISABLE_BROKER 
GO
ALTER DATABASE [dbEvent] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [dbEvent] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [dbEvent] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [dbEvent] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [dbEvent] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [dbEvent] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [dbEvent] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [dbEvent] SET RECOVERY FULL 
GO
ALTER DATABASE [dbEvent] SET  MULTI_USER 
GO
ALTER DATABASE [dbEvent] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [dbEvent] SET DB_CHAINING OFF 
GO
ALTER DATABASE [dbEvent] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [dbEvent] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [dbEvent] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [dbEvent] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'dbEvent', N'ON'
GO
ALTER DATABASE [dbEvent] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [eventLogin]

-- %%
USE [dbEvent]
GO

-- %%
/****** Object:  User [eventLogin]    Script Date: 2022/12/23 下午 04:34:45 ******/
CREATE USER [eventLogin] FOR LOGIN [eventLogin] WITH DEFAULT_SCHEMA=[dbo]
GO

-- %%
ALTER ROLE [db_owner] ADD MEMBER [eventLogin]
GO

-- %% [markdown]
-- # [dbo].[Categories]

-- %%
/****** Object:  Table [dbo].[Categories]    Script Date: 2022/12/23 下午 04:34:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Categories](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[CategoryName] [nvarchar](30) NOT NULL,
	[DisplayOrder] [int] NOT NULL,
 CONSTRAINT [PK_Categories] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Member]

-- %%
/****** Object:  Table [dbo].[Member]    Script Date: 2022/12/23 下午 04:34:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Member](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Name] [nvarchar](50) NOT NULL,
	[Account] [nvarchar](50) NOT NULL,
	[Password] [nvarchar](50) NOT NULL,
	[CellPhone] [nvarchar](50) NOT NULL,
 CONSTRAINT [PK_Member] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Products]

-- %%
/****** Object:  Table [dbo].[Products]    Script Date: 2022/12/23 下午 04:34:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Products](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[CategoryId] [int] NOT NULL,
	[ProductName] [nvarchar](50) NOT NULL,
	[UnitPrice] [int] NOT NULL,
 CONSTRAINT [PK_Products] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Registers]

-- %%
/****** Object:  Table [dbo].[Registers]    Script Date: 2022/12/23 下午 04:34:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Registers](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Name] [nvarchar](50) NOT NULL,
	[Email] [nvarchar](100) NOT NULL,
	[CreateTime] [datetime] NOT NULL,
 CONSTRAINT [PK_Registers] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Categories]

-- %%
SET IDENTITY_INSERT [dbo].[Categories] ON 
INSERT [dbo].[Categories] ([Id], [CategoryName], [DisplayOrder]) VALUES (1, N'3C', 10)
INSERT [dbo].[Categories] ([Id], [CategoryName], [DisplayOrder]) VALUES (2, N'家電', 20)
INSERT [dbo].[Categories] ([Id], [CategoryName], [DisplayOrder]) VALUES (3, N'生活用品', 30)
INSERT [dbo].[Categories] ([Id], [CategoryName], [DisplayOrder]) VALUES (4, N'3C', 10)
INSERT [dbo].[Categories] ([Id], [CategoryName], [DisplayOrder]) VALUES (5, N'家電', 20)
INSERT [dbo].[Categories] ([Id], [CategoryName], [DisplayOrder]) VALUES (6, N'生活用品', 30)
INSERT [dbo].[Categories] ([Id], [CategoryName], [DisplayOrder]) VALUES (7, N'3C', 10)
INSERT [dbo].[Categories] ([Id], [CategoryName], [DisplayOrder]) VALUES (8, N'家電', 20)
INSERT [dbo].[Categories] ([Id], [CategoryName], [DisplayOrder]) VALUES (9, N'生活用品', 30)
SET IDENTITY_INSERT [dbo].[Categories] OFF
GO

-- %% [markdown]
-- # [dbo].[Products]

-- %%
SET IDENTITY_INSERT [dbo].[Products] ON 
INSERT [dbo].[Products] ([Id], [CategoryId], [ProductName], [UnitPrice]) VALUES (1, 1, N'HP Printer', 3000)
INSERT [dbo].[Products] ([Id], [CategoryId], [ProductName], [UnitPrice]) VALUES (2, 1, N'華碩A320 桌機', 20000)
INSERT [dbo].[Products] ([Id], [CategoryId], [ProductName], [UnitPrice]) VALUES (3, 1, N'華碩 Zenbook 14 UX3402ZA', 34900)
INSERT [dbo].[Products] ([Id], [CategoryId], [ProductName], [UnitPrice]) VALUES (4, 2, N'Dyson Cyclone V10 Fluffy SV12 無線吸塵器', 12900)
INSERT [dbo].[Products] ([Id], [CategoryId], [ProductName], [UnitPrice]) VALUES (5, 2, N'SANSUI 山水 1.8L大容量304不銹鋼電茶壺二入組', 788)
INSERT [dbo].[Products] ([Id], [CategoryId], [ProductName], [UnitPrice]) VALUES (6, 2, N'大日 Dainichi 煤油暖氣機', 10900)
INSERT [dbo].[Products] ([Id], [CategoryId], [ProductName], [UnitPrice]) VALUES (7, 2, N'PHILIPS 飛利浦  智能護齦音波震動牙刷 HX6803/02', 2490)
INSERT [dbo].[Products] ([Id], [CategoryId], [ProductName], [UnitPrice]) VALUES (8, 3, N'Boden-奧洛4尺多功能收納升降大茶几', 5599)
INSERT [dbo].[Products] ([Id], [CategoryId], [ProductName], [UnitPrice]) VALUES (9, 3, N'Flexispot 單螢幕懸浮旋臂支架 - 黑色', 1912)
INSERT [dbo].[Products] ([Id], [CategoryId], [ProductName], [UnitPrice]) VALUES (10, 3, N'Flexispot 簡易式氣壓升降工作台', 3390)
INSERT [dbo].[Products] ([Id], [CategoryId], [ProductName], [UnitPrice]) VALUES (11, 3, N'TOTO TCF23710ATW C2 溫水洗淨便座', 8990)
INSERT [dbo].[Products] ([Id], [CategoryId], [ProductName], [UnitPrice]) VALUES (12, 3, N'象印*0.82L*SLiT不鏽鋼真空保溫瓶', 690)
INSERT [dbo].[Products] ([Id], [CategoryId], [ProductName], [UnitPrice]) VALUES (13, 1, N'HP Printer', 3000)
INSERT [dbo].[Products] ([Id], [CategoryId], [ProductName], [UnitPrice]) VALUES (14, 1, N'華碩A320 桌機', 20000)
INSERT [dbo].[Products] ([Id], [CategoryId], [ProductName], [UnitPrice]) VALUES (15, 1, N'華碩 Zenbook 14 UX3402ZA', 34900)
INSERT [dbo].[Products] ([Id], [CategoryId], [ProductName], [UnitPrice]) VALUES (16, 2, N'Dyson Cyclone V10 Fluffy SV12 無線吸塵器', 12900)
INSERT [dbo].[Products] ([Id], [CategoryId], [ProductName], [UnitPrice]) VALUES (17, 2, N'SANSUI 山水 1.8L大容量304不銹鋼電茶壺二入組', 788)
INSERT [dbo].[Products] ([Id], [CategoryId], [ProductName], [UnitPrice]) VALUES (18, 2, N'大日 Dainichi 煤油暖氣機', 10900)
INSERT [dbo].[Products] ([Id], [CategoryId], [ProductName], [UnitPrice]) VALUES (19, 2, N'PHILIPS 飛利浦  智能護齦音波震動牙刷 HX6803/02', 2490)
INSERT [dbo].[Products] ([Id], [CategoryId], [ProductName], [UnitPrice]) VALUES (20, 3, N'Boden-奧洛4尺多功能收納升降大茶几', 5599)
INSERT [dbo].[Products] ([Id], [CategoryId], [ProductName], [UnitPrice]) VALUES (21, 3, N'Flexispot 單螢幕懸浮旋臂支架 - 黑色', 1912)
INSERT [dbo].[Products] ([Id], [CategoryId], [ProductName], [UnitPrice]) VALUES (22, 3, N'Flexispot 簡易式氣壓升降工作台', 3390)
INSERT [dbo].[Products] ([Id], [CategoryId], [ProductName], [UnitPrice]) VALUES (23, 3, N'TOTO TCF23710ATW C2 溫水洗淨便座', 8990)
INSERT [dbo].[Products] ([Id], [CategoryId], [ProductName], [UnitPrice]) VALUES (24, 3, N'象印*0.82L*SLiT不鏽鋼真空保溫瓶', 690)
INSERT [dbo].[Products] ([Id], [CategoryId], [ProductName], [UnitPrice]) VALUES (25, 1, N'HP Printer', 3000)
INSERT [dbo].[Products] ([Id], [CategoryId], [ProductName], [UnitPrice]) VALUES (26, 1, N'華碩A320 桌機', 20000)
INSERT [dbo].[Products] ([Id], [CategoryId], [ProductName], [UnitPrice]) VALUES (27, 1, N'華碩 Zenbook 14 UX3402ZA', 34900)
INSERT [dbo].[Products] ([Id], [CategoryId], [ProductName], [UnitPrice]) VALUES (28, 2, N'Dyson Cyclone V10 Fluffy SV12 無線吸塵器', 12900)
INSERT [dbo].[Products] ([Id], [CategoryId], [ProductName], [UnitPrice]) VALUES (29, 2, N'SANSUI 山水 1.8L大容量304不銹鋼電茶壺二入組', 788)
INSERT [dbo].[Products] ([Id], [CategoryId], [ProductName], [UnitPrice]) VALUES (30, 2, N'大日 Dainichi 煤油暖氣機', 10900)
INSERT [dbo].[Products] ([Id], [CategoryId], [ProductName], [UnitPrice]) VALUES (31, 2, N'PHILIPS 飛利浦  智能護齦音波震動牙刷 HX6803/02', 2490)
INSERT [dbo].[Products] ([Id], [CategoryId], [ProductName], [UnitPrice]) VALUES (32, 3, N'Boden-奧洛4尺多功能收納升降大茶几', 5599)
INSERT [dbo].[Products] ([Id], [CategoryId], [ProductName], [UnitPrice]) VALUES (33, 3, N'Flexispot 單螢幕懸浮旋臂支架 - 黑色', 1912)
INSERT [dbo].[Products] ([Id], [CategoryId], [ProductName], [UnitPrice]) VALUES (34, 3, N'Flexispot 簡易式氣壓升降工作台', 3390)
INSERT [dbo].[Products] ([Id], [CategoryId], [ProductName], [UnitPrice]) VALUES (35, 3, N'TOTO TCF23710ATW C2 溫水洗淨便座', 8990)
INSERT [dbo].[Products] ([Id], [CategoryId], [ProductName], [UnitPrice]) VALUES (36, 3, N'象印*0.82L*SLiT不鏽鋼真空保溫瓶', 690)
SET IDENTITY_INSERT [dbo].[Products] OFF
GO

-- %% [markdown]
-- # [dbo].[Registers]

-- %%
SET IDENTITY_INSERT [dbo].[Registers] ON 
INSERT [dbo].[Registers] ([Id], [Name], [Email], [CreateTime]) VALUES (1, N'cc', N'123', CAST(N'2022-12-22T00:00:00.000' AS DateTime))
INSERT [dbo].[Registers] ([Id], [Name], [Email], [CreateTime]) VALUES (2, N'ee', N'789', CAST(N'2022-12-21T10:19:10.710' AS DateTime))
SET IDENTITY_INSERT [dbo].[Registers] OFF
GO

-- %% [markdown]
-- # [FK_Products_Categories]

-- %%
ALTER TABLE [dbo].[Products]  WITH CHECK ADD  CONSTRAINT [FK_Products_Categories] FOREIGN KEY([CategoryId])
REFERENCES [dbo].[Categories] ([Id])
GO
ALTER TABLE [dbo].[Products] CHECK CONSTRAINT [FK_Products_Categories]
GO

-- %% [markdown]
-- # [dbEvent]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [dbEvent] SET  READ_WRITE 
GO
